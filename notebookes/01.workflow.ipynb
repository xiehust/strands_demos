# %%
from strands import Agent
from strands_tools import workflow

# Create an agent with workflow capability
agent = Agent(tools=[workflow])

# Create a multi-agent workflow
agent.tool.workflow(
    action="create",
    workflow_id="data_analysis",
    tasks=[
        {
            "task_id": "data_extraction",
            "description": "Extract key financial data from the quarterly report",
            "system_prompt": "You extract and structure financial data from reports.",
            "priority": 5
        },
        {
            "task_id": "trend_analysis",
            "description": "Analyze trends in the data compared to previous quarters",
            "dependencies": ["data_extraction"],
            "system_prompt": "You identify trends in financial time series.",
            "priority": 3
        },
        {
            "task_id": "report_generation",
            "description": "Generate a comprehensive analysis report",
            "dependencies": ["trend_analysis"],
            "system_prompt": "You create clear financial analysis reports.",
            "priority": 2
        }
    ]
)

# Execute workflow (parallel processing where possible)
agent.tool.workflow(action="start", workflow_id="data_analysis")

# Check results
status = agent.tool.workflow(action="status", workflow_id="data_analysis")
# Out:
# I don't see a quarterly report attached to your message. To extract key financial data from a quarterly report, I would need you to provide the actual report text or upload the document.
#
# Once you share the quarterly report, I can extract important financial information such as:
#
# - Revenue and revenue growth
# - Gross profit and margins
# - Operating income/loss
# - Net income/loss
# - Earnings per share
# - Cash flow metrics
# - Balance sheet highlights
# - Segment performance
# - Guidance for future quarters
# - Any significant changes in financial position
#
# Please share the quarterly report and I'll analyze the key financial data for you.I don't have any data to analyze at the moment. To provide meaningful trend analysis comparing quarterly data, I would need you to share:
#
# 1. The current quarterly report
# 2. Information from previous quarters for comparison
#
# Without this information, I can't identify specific trends in metrics like revenue growth, profit margins, expense ratios, or other key financial indicators across quarters.
#
# Once you provide the quarterly data (either current and previous reports or a summary of key metrics over multiple quarters), I can help analyze trends by:
#
# - Identifying quarter-over-quarter and year-over-year changes
# - Spotting patterns in financial performance
# - Analyzing seasonal variations
# - Highlighting improvements or deteriorations in key metrics
# - Examining the effectiveness of any strategic initiatives
#
# Please share the relevant quarterly data, and I'll be happy to analyze the trends for you.# Request for Information to Generate Comprehensive Analysis Report
#
# I'd be happy to create a comprehensive analysis report for you, but I currently don't have any data to analyze. To generate a thorough and useful report, I'll need you to provide:
#
# ## Information Needed
#
# 1. **Financial data from current quarter**
#    - Income statement metrics (revenue, expenses, profits)
#    - Balance sheet highlights
#    - Cash flow information
#
# 2. **Historical data from previous quarters**
#    - At least 2-4 previous quarters for trend analysis
#    - Year-over-year comparisons where available
#
# 3. **Context for the analysis**
#    - Industry or sector
#    - Company size/type
#    - Specific areas of interest or concern
#    - Any significant events during the reporting periods
#
# ## Report I Can Deliver
#
# Once you provide the necessary information, I can generate a comprehensive report that includes:
#
# - Executive summary
# - Detailed financial performance analysis
# - Trend identification and visualization
# - Comparative analysis against previous quarters
# - Key ratio analysis and interpretation
# - Potential risk factors and opportunities
# - Strategic recommendations based on data insights
#
# Please share the relevant financial information, and I'll create a tailored analysis report that meets your needs.

# %%
status
# Out:
# {'toolUseId': 'tooluse_workflow_489709207',
#  'status': 'success',
#  'content': [{'text': 'Workflow ID: data_analysis\nOverall Status: completed\nProgress: 100.0% (3/3)\nActive Tasks: 3\nCompleted Tasks: 3\nPending Tasks: 0\nFailed Tasks: 0\nActive Workers: 0/8\n\nTask Details:\n\nTask: data_extraction\nDescription: Extract key financial data from the quarterly report\nStatus: completed\nPriority: 5\nDuration: 6.04s\n\nTask: trend_analysis\nDescription: Analyze trends in the data compared to previous quarters\nStatus: completed\nPriority: 3\nDuration: 5.91s\n\nTask: report_generation\nDescription: Generate a comprehensive analysis report\nStatus: completed\nPriority: 2\nDuration: 8.23s'}]}

# %%
"""
# Agentic Workflow: Research Assistant

This example demonstrates an agentic workflow using Strands agents with web research capabilities.

## Key Features
- Specialized agent roles working in sequence
- Direct passing of information between workflow stages
- Web research using http_request and retrieve tools
- Fact-checking and information synthesis

## How to Run
1. Navigate to the example directory
2. Run: python research_assistant.py
3. Enter queries or claims at the prompt

## Example Queries
- "Thomas Edison invented the light bulb"
- "Tuesday comes before Monday in the week"

## Workflow Process
1. Researcher Agent: Gathers web information using multiple tools
2. Analyst Agent: Verifies facts and synthesizes findings
3. Writer Agent: Creates final report
"""

from strands import Agent
from strands_tools import http_request


def run_research_workflow(user_input):
    """
    Run a three-agent workflow for research and fact-checking with web sources.
    Shows progress logs during execution but presents only the final report to the user.
    
    Args:
        user_input: Research query or claim to verify
        
    Returns:
        str: The final report from the Writer Agent
    """
    
    print(f"\nProcessing: '{user_input}'")
    
    # Step 1: Researcher Agent with enhanced web capabilities
    print("\nStep 1: Researcher Agent gathering web information...")
    
    researcher_agent = Agent(
        system_prompt=(
            "You are a Researcher Agent that gathers information from the web. "
            "1. Determine if the input is a research query or factual claim "
            "2. Use your research tools (http_request, retrieve) to find relevant information "
            "3. Include source URLs and keep findings under 500 words"
        ),
        callback_handler=None,
        tools=[http_request]
    )
    
    researcher_response = researcher_agent(
        f"Research: '{user_input}'. Use your available tools to gather information from reliable sources. "
        f"Focus on being concise and thorough, but limit web requests to 1-2 sources.",
    )
    
    # Extract only the relevant content from the researcher response
    research_findings = str(researcher_response)
    
    print("Research complete")
    print("Passing research findings to Analyst Agent...\n")
    
    # Step 2: Analyst Agent to verify facts
    print("Step 2: Analyst Agent analyzing findings...")
    
    analyst_agent = Agent(
        system_prompt=(
            "You are an Analyst Agent that verifies information. "
            "1. For factual claims: Rate accuracy from 1-5 and correct if needed "
            "2. For research queries: Identify 3-5 key insights "
            "3. Evaluate source reliability and keep analysis under 400 words"
        ),
        callback_handler=None
    )

    analyst_response = analyst_agent(
        f"Analyze these findings about '{user_input}':\n\n{research_findings}",
    )
    
    # Extract only the relevant content from the analyst response
    analysis = str(analyst_response)
    
    print("Analysis complete")
    print("Passing analysis to Writer Agent...\n")
    
    # Step 3: Writer Agent to create report
    print("Step 3: Writer Agent creating final report...")
    
    writer_agent = Agent(
        system_prompt=(
            "You are a Writer Agent that creates clear reports. "
            "1. For fact-checks: State whether claims are true or false "
            "2. For research: Present key insights in a logical structure "
            "3. Keep reports under 500 words with brief source mentions"
        )
    )
    
    # Execute the Writer Agent with the analysis (output is shown to user)
    final_report = writer_agent(
        f"Create a report on '{user_input}' based on this analysis:\n\n{analysis}"
    )
    
    print("Report creation complete")
    
    # Return the final report
    return final_report
# Out:
# Warning: Input is not a terminal (fd=0).

# %%
def custom_callback_handler(**kwargs):
    # Process stream data
    if "data" in kwargs:
        print(f"{kwargs['data']}",end='')
    elif "current_tool_use" in kwargs and kwargs["current_tool_use"].get("name"):
        print(f"\nUSING TOOL: {kwargs['current_tool_use']['name']} / {kwargs['current_tool_use']['input']}")

# %%
text="""# AWS intros Strands Agents SDK

Many developers find agentic AI difficult, so the new SDK is meant to help them deploy the technology and connect models and tools. The toolkit also aligns with AWS' SDLC strategy.
Esther Shittu
By
Esther Shittu, News Writer
Published: 16 May 2025
AWS on Friday introduced Strands Agents, an open source SDK.

Strands Agents is a model-driven toolkit for building and running AI agents with a few lines of code, according to AWS. With Strands, developers can define a prompt and a list of tools in code to build an agent, test it and deploy it to the cloud, the vendor said.


AWS said the SDK connects the two components: the model and tools. It plans the agent's next steps and executes tools with advanced reasoning capabilities.

Agentic challenges for developers
Strands Agents is AWS's attempt to help developers integrate agentic AI into their workflows. Currently, developers have divergent points of view regarding agentic AI tools.

"Some embrace it and some remain skeptical," said Rachel Stephens, an analyst at RedMonk.

Part of the challenge is that many developers find the current approach of developing and managing an agentic workflow difficult.

"Application developers struggle to find the right balance between taking advantage of the flexibility of LLM [large language model]-driven task execution on the one hand and controlling the probabilistic character of the results of these agent workflows on the other," said Torsten Volk, an analyst at Omdia, a division of Informa TechTarget.

He added that workflow-based tools often require more skill and expertise than typically found in an enterprise, meaning many AI projects face the threat of abandonment. With Strands, AWS promises developers do not need "hardcoded workflows," Volk continued. Instead, they can use an LLM of their choice to complete their tasks.

"Developers will be drawn by Strands if it manages to replace complex workflows with a simpler approach that relies on LLMs to structure how models are used, thoughts are chained and tools are called," Volk said. "The availability of a large tool library will be another important factor, as tool integration is another critical developer pain point."

## AWS strategy
Strands Agents also aligns with AWS's strategy of integrating better with the software development lifecycle (SDLC).

"AWS has long been a destination for production code but has historically struggled to gain traction as a center of gravity for other parts of the SDLC," Stephens said.

The cloud provider has recently addressed this with launches that include agent integrations into GitLab and GitHub.

"These integrations indicate an ecosystem focus and an intention to build integrations that stretch across the SDLC," Stephens continued. She added that Strands Agents is also an SDLC play.

"It's designed to help developers design and build agents, test them locally and deploy them to the cloud," she said.

The integration angle is more tangential, although AWS uses independent generative AI vendor Anthropic's model complex protocol (MCP), "which opens a lot of ecosystem doors," Stephens said. "MCP is the de facto standard for connecting agentic tools."

Strands Agents can run anywhere and support any model with reasoning and tool use capabilities, including models in Amazon Bedrock and Ollama. As an open source system, Strands Agents includes contributions from others in the community, including Accenture, Anthropic, Meta and PwC. Developers can start using the tools on GitHub now.

Meanwhile, OpenAI on Friday introduced Codex, a cloud-based software engineering agent that can work on tasks such as writing features, answering questions about a codebase and fixing bugs in parallel.

It is powered by codex-1, a version of OpenAI's o3 LLM that is optimized for software engineering and trained with reinforcement learning, OpenAI said.

The new agent will now be rolled out to ChatGPT Pro, Enterprise and Team users. Plus and Edu users will soon be able to use it, too.

Esther Shittu is an Informa TechTarget news writer and podcast host covering AI software and systems.
"""

# %%
from mcp import stdio_client, StdioServerParameters
from strands import Agent
from strands.tools.mcp import MCPClient
from strands_tools import workflow

# Create an agent with these tools
agent_translation = Agent(tools=[workflow],callback_handler=custom_callback_handler)

agent_translation(f"""
Create a translation workflow with the following tasks:
1. A AI tech translator translate news content to Chinese
2. Review translation and provide feedbacks (depends on task 1)
3. Refine the translation based on feedbacks (depends on task 2)
4. Generate 3~5 insights (depends on task 3)
""")

# text="""# AWS intros Strands Agents SDK

# Many developers find agentic AI difficult, so the new SDK is meant to help them deploy the technology and connect models and tools. The toolkit also aligns with AWS' SDLC strategy.
# Esther Shittu
# By..."""

agent_translation(f"translate {text}")
# Out:
# I'll help you create a translation workflow with the tasks you described. Let me set this up using the workflow function.
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
#
# I've created a translation workflow named "news_translation_workflow" with the following tasks in sequence:
#
# 1. **Task: Translate to Chinese**
#    - Description: Translate news content to Chinese
#    - System prompt: Designed for an AI tech translator to maintain meaning, tone, and technical accuracy
#
# 2. **Task: Review Translation**
#    - Description: Review translation and provide feedbacks
#    - Depends on: The initial translation task
#    - System prompt: Set up for a language expert to review for accuracy, naturalness, and terminology
#
# 3. **Task: Refine Translation**
#    - Description: Refine the translation based on feedbacks
#    - Depends on: The review task
#    - System prompt: For a professional translator to improve the translation based on feedback
#
# 4. **Task: Generate Insights**
#    - Description: Generate 3-5 insights
#    - Depends on: The refined translation
#    - System prompt: Set to extract 3-5 key insights valuable for Chinese-speaking readers
#
# The workflow has been successfully created with the proper dependency chain. To start the workflow, you would need to run it with the "start" action and provide the news content to be translated.
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '\n\nI\'ve created a translation workflow named "news_translation_workflow" with the following tasks in sequence:\n\n1. **Task: Translate to Chinese**\n   - Description: Translate news content to Chinese\n   - System prompt: Designed for an AI tech translator to maintain meaning, tone, and technical accuracy\n\n2. **Task: Review Translation**\n   - Description: Review translation and provide feedbacks\n   - Depends on: The initial translation task\n   - System prompt: Set up for a language expert to review for accuracy, naturalness, and terminology\n\n3. **Task: Refine Translation**\n   - Description: Refine the translation based on feedbacks\n   - Depends on: The review task\n   - System prompt: For a professional translator to improve the translation based on feedback\n\n4. **Task: Generate Insights**\n   - Description: Generate 3-5 insights\n   - Depends on: The refined translation\n   - System prompt: Set to extract 3-5 key insights valuable for Chinese-speaking readers\n\nThe workflow has been successfully created with the proper dependency chain. To start the workflow, you would need to run it with the "start" action and provide the news content to be translated.'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={'workflow': ToolMetrics(tool={'toolUseId': 'tooluse_dERHQ9fcRwu4Nxcacohw6g', 'name': 'workflow', 'input': {'action': 'create', 'workflow_id': 'news_translation_workflow', 'tasks': [{'task_id': 'translate_to_chinese', 'description': 'Translate news content to Chinese', 'system_prompt': 'You are an AI tech translator. Translate the provided news content from English to Chinese, maintaining the original meaning, tone, and technical accuracy.', 'priority': 3}, {'task_id': 'review_translation', 'description': 'Review translation and provide feedbacks', 'system_prompt': 'You are a language expert specialized in English-Chinese translations. Review the provided translation and give detailed feedback on accuracy, naturalness, and technical terminology.', 'dependencies': ['translate_to_chinese'], 'priority': 3}, {'task_id': 'refine_translation', 'description': 'Refine the translation based on feedbacks', 'system_prompt': 'You are a professional translator. Refine the Chinese translation based on the feedback provided, improving accuracy and naturalness while ensuring technical terminology is correctly translated.', 'dependencies': ['review_translation'], 'priority': 3}, {'task_id': 'generate_insights', 'description': 'Generate 3~5 insights', 'system_prompt': 'Based on the refined translation, generate 3-5 key insights from the content that would be valuable for Chinese-speaking readers.', 'dependencies': ['refine_translation'], 'priority': 3}]}}, call_count=1, success_count=1, error_count=0, total_time=0.40180134773254395)}, cycle_durations=[6.509925842285156], traces=[<strands.telemetry.metrics.Trace object at 0x7f5a8abf31b0>, <strands.telemetry.metrics.Trace object at 0x7f5a67a77430>], accumulated_usage={'inputTokens': 1936, 'outputTokens': 365, 'totalTokens': 2301}, accumulated_metrics={'latencyMs': 16538}), state={})
# I'd be happy to translate news content to Chinese for you. However, I don't see any specific news content provided in your message that needs translation.
#
# Could you please share the English news content you'd like me to translate to Chinese? Once you provide the text, I can create an accurate Chinese translation for you.I don't see any translation that I can review or provide feedback on. For me to review a translation and provide feedback, you would need to provide:
#
# 1. The original text (in the source language)
# 2. The translated text (that you want me to review)
#
# Once you share these materials, I can:
# - Assess the accuracy of the translation
# - Check for grammatical errors
# - Evaluate word choice and natural expression
# - Suggest improvements
# - Comment on any cultural adaptations that might be needed
#
# Please share the translation you'd like me to review, along with the original text if possible.I understand you'd like me to refine a translation based on feedback, but there isn't any translation or feedback provided in our conversation that I can work with.
#
# For me to refine a translation based on feedback, I would need:
#
# 1. The original text
# 2. An existing translation
# 3. The feedback that has been provided on that translation
#
# Once you share these elements with me, I'd be happy to revise and improve the translation according to the feedback received.
#
# If you have a translation that needs refinement, please share it along with the original text and any specific feedback you've received about it.I understand you'd like me to generate 3-5 insights, but I'm not sure what topic or data you'd like these insights about. To provide meaningful insights, I need some context or subject matter to analyze.
#
# I'd be happy to generate insights about:
# - A specific industry or market
# - A current event or news story
# - Business trends
# - Consumer behavior
# - Technology adoption
# - Cultural phenomena
# - Data you can provide
#
# Please let me know what topic you're interested in, and I'll generate 3-5 thoughtful insights based on that information.

# %%
agent_translation(f"translate {text}")
# Out:
# I'll help you use the translation workflow you created to translate this news article. Let me start this workflow:
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
#
# Let me check the status of the workflow to see the results:
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
# USING TOOL: workflow
#
#
# The workflow has completed successfully! All four tasks (translate, review, refine, and generate insights) have been processed. I'll provide the translated content from each step:
#
# ## Translation Results
#
# ### Initial Chinese Translation:
# ```
# # AWS推出Strands Agents SDK
#
# 许多开发者发现代理型人工智能难以使用，因此新的SDK旨在帮助他们部署该技术并连接模型和工具。该工具包还与AWS的SDLC策略保持一致。
#
# Esther Shittu
# 作者：Esther Shittu，新闻记者
# 发布日期：2025年5月16日
#
# AWS周五推出了Strands Agents，一个开源SDK。
#
# 据AWS介绍，Strands Agents是一个模型驱动的工具包，用几行代码构建和运行AI代理。使用Strands，开发者可以定义提示和工具列表来构建代理，测试它并将其部署到云端。
#
# AWS表示，该SDK连接了两个组件：模型和工具。它计划代理的下一步行动并使用先进的推理能力执行工具。
#
# 开发者面临的代理挑战
# Strands Agents是AWS帮助开发者将代理型AI整合到工作流程中的尝试。目前，开发者对代理型AI工具持有不同观点。
#
# "有些人欣然接受，有些人则保持怀疑，"RedMonk分析师Rachel Stephens表示。
#
# 部分挑战在于，许多开发者发现目前开发和管理代理工作流的方法很困难。
#
# "应用程序开发者在一方面利用LLM（大型语言模型）驱动的任务执行灵活性和另一方面控制这些代理工作流结果的概率特性之间，难以找到正确平衡，"Omdia（Informa TechTarget的一个部门）分析师Torsten Volk说。
#
# 他补充说，基于工作流的工具通常需要比企业中典型找到的更多技能和专业知识，这意味着许多AI项目面临被放弃的威胁。通过Strands，AWS承诺开发者不需要"硬编码工作流"，Volk继续说。相反，他们可以使用自己选择的LLM来完成任务。
#
# "如果Strands能够用一种更简单的方法替代复杂工作流，依靠LLM来构建如何使用模型、思考链和调用工具，开发者会被吸引，"Volk说。"大型工具库的可用性将是另一个重要因素，因为工具集成是另一个关键的开发者痛点。"
#
# ## AWS策略
# Strands Agents还与AWS更好地集成软件开发生命周期（SDLC）的战略保持一致。
#
# "AWS长期以来一直是生产代码的目的地，但历史上难以在SDLC其他部分获得牵引力，"Stephens说。
#
# 该云提供商最近通过包括将代理集成到GitLab和GitHub中的发布来解决这一问题。
#
# "这些集成表明了生态系统焦点和构建贯穿SDLC的集成的意图，"Stephens继续说。她补充说，Strands Agents也是SDLC的一部分。
#
# "它旨在帮助开发者设计和构建代理，在本地测试它们并将它们部署到云端，"她说。
#
# 虽然集成角度更为切线，但AWS使用独立生成式AI供应商Anthropic的模型复杂协议（MCP），"这打开了许多生态系统的门，"Stephens说。"MCP是连接代理工具的事实标准。"
#
# Strands Agents可以在任何地方运行，并支持任何具有推理和工具使用能力的模型，包括Amazon Bedrock和Ollama中的模型。作为开源系统，Strands Agents包括来自社区其他成员的贡献，包括埃森哲、Anthropic、Meta和普华永道。开发者现在可以在GitHub上开始使用这些工具。
#
# 与此同时，OpenAI周五推出了Codex，一个基于云的软件工程代理，可以并行处理编写功能、回答关于代码库的问题和修复错误等任务。
#
# 它由codex-1提供支持，这是OpenAI的o3 LLM的一个版本，针对软件工程进行了优化，并通过强化学习进行了训练，OpenAI表示。
#
# 新代理现在将向ChatGPT Pro、Enterprise和Team用户推出。Plus和Edu用户也将很快能够使用它。
#
# Esther Shittu是Informa TechTarget的新闻作家和播客主持人，报道AI软件和系统。
# ```
#
# ### Review Feedback:
# ```
# 整体来说，这篇翻译质量较高，大部分内容准确传达了原文的意思。以下是一些具体反馈和建议：
#
# 1. 标题和小标题翻译准确
# 2. 技术术语如"SDK"、"SDLC"、"LLM"等保留了英文，这是正确的做法
#
# 需要改进的地方：
#
# 1. "代理型人工智能"可改为更专业的"智能体AI"或"AI智能体"（agentic AI的标准翻译）
# 2. "几行代码构建和运行AI代理"中的"代理"应统一为"智能体"
# 3. "工具包"和"工具集"的翻译可以更加一致
# 4. "部署到云端"可以考虑译为"部署至云环境"，更符合技术文档表述
# 5. "概率特性"（probabilistic character）的翻译不够准确，可改为"概率性特征"或"不确定性特征"
# 6. "埃森哲"应直接使用英文名称"Accenture"，因为这是公司名称
# 7. 部分句子结构可以调整得更符合中文表达习惯，比如"应用程序开发者在...之间，难以找到正确平衡"可改为"应用程序开发者难以在...之间找到正确平衡"
# 8. 日期格式"2025年5月16日"符合中文习惯，翻译正确
#
# 总体建议：对技术术语的翻译需要更加一致，句式可以更加符合中文的表达习惯，适当增加连接词使文章更流畅。
# ```
#
# ### Refined Translation:
# ```
# # AWS推出Strands Agents SDK
#
# 许多开发者发现AI智能体（agentic AI）难以使用，因此新的SDK旨在帮助他们部署该技术并连接模型和工具。该工具包还与AWS的SDLC策略保持一致。
#
# Esther Shittu
# 作者：Esther Shittu，新闻记者
# 发布日期：2025年5月16日
#
# AWS周五推出了Strands Agents，一个开源SDK。
#
# 据AWS介绍，Strands Agents是一个模型驱动的工具包，用几行代码即可构建和运行AI智能体。使用Strands，开发者可以定义提示和工具列表来构建智能体，测试它并将其部署至云环境。
#
# AWS表示，该SDK连接了两个核心组件：模型和工具。它规划智能体的下一步行动并利用先进的推理能力执行工具。
#
# 开发者面临的智能体挑战
# Strands Agents是AWS帮助开发者将AI智能体整合到工作流程中的尝试。目前，开发者对AI智能体工具持有不同观点。
#
# "有些人欣然接受，有些人则保持怀疑，"RedMonk分析师Rachel Stephens表示。
#
# 部分挑战在于，许多开发者发现目前开发和管理智能体工作流的方法很困难。
#
# "应用程序开发者难以在利用LLM（大型语言模型）驱动的任务执行灵活性和控制这些智能体工作流结果的不确定性特征之间找到正确平衡，"Omdia（Informa TechTarget的一个部门）分析师Torsten Volk说。
#
# 他补充说，基于工作流的工具通常需要比企业中通常具备的更多技能和专业知识，这意味着许多AI项目面临被放弃的风险。通过Strands，AWS承诺开发者不需要"硬编码工作流"。相反，他们可以使用自己选择的LLM来完成任务。
#
# "如果Strands能够用一种更简单的方法替代复杂工作流，依靠LLM来构建如何使用模型、思考链和调用工具，开发者会被吸引，"Volk说。"大型工具库的可用性将是另一个重要因素，因为工具集成是另一个关键的开发者痛点。"
#
# ## AWS策略
# Strands Agents还与AWS更好地集成软件开发生命周期（SDLC）的战略保持一致。
#
# "AWS长期以来一直是生产代码的目的地，但历史上难以在SDLC其他部分获得牵引力，"Stephens说。
#
# 该云提供商最近通过包括将智能体集成到GitLab和GitHub中的发布来解决这一问题。
#
# "这些集成表明了生态系统焦点和构建贯穿SDLC的集成的意图，"Stephens继续说道。她补充说，Strands Agents也是SDLC战略的一部分。
#
# "它旨在帮助开发者设计和构建智能体，在本地测试它们并将它们部署至云环境，"她说。
#
# 虽然集成角度相对间接，但AWS使用独立生成式AI供应商Anthropic的模型复杂协议（MCP），"这打开了许多生态系统的大门，"Stephens说。"MCP是连接智能体工具的事实标准。"
#
# Strands Agents可以在任何地方运行，并支持任何具有推理和工具使用能力的模型，包括Amazon Bedrock和Ollama中的模型。作为开源系统，Strands Agents包括来自社区其他成员的贡献，包括Accenture、Anthropic、Meta和PwC。开发者现在可以在GitHub上开始使用这些工具。
#
# 与此同时，OpenAI周五推出了Codex，一个基于云的软件工程智能体，可以并行处理编写功能、回答关于代码库的问题和修复错误等任务。
#
# 它由codex-1提供支持，这是OpenAI的o3 LLM的一个版本，针对软件工程进行了优化，并通过强化学习进行了训练，OpenAI表示。
#
# 新智能体现在将向ChatGPT Pro、Enterprise和Team用户推出。Plus和Edu用户也将很快能够使用它。
#
# Esther Shittu是Informa TechTarget的新闻作家和播客主持人，报道AI软件和系统。
# ```
#
# ### Key Insights Generated:
# ```
# # 关键见解
#
# 1. **AI智能体开发简化的趋势**：AWS通过Strands Agents展示了行业正在努力简化智能体AI的开发过程，让普通开发者无需深厚专业知识也能部署AI智能体。这表明AI工具正在从专家领域向主流开发者社区过渡。
#
# 2. **SDLC整合是云服务商的新战略方向**：AWS将Strands Agents与软件开发生命周期(SDLC)整合的努力，表明主要云服务提供商正扩展其价值主张，从仅提供基础设施向成为开发流程的核心部分转变。
#
# 3. **模型复杂协议(MCP)成为行业标准**：文章指出MCP成为连接智能体工具的"事实标准"，这凸显了在快速发展的AI领域中，开放标准和互操作性变得越来越重要，可能会影响未来AI开发的格局。
#
# 4. **开源协作成为AI发展关键动力**：Strands Agents作为开源系统接受了包括Accenture、Anthropic、Meta和PwC在内的多家公司的贡献，展示了开源合作在推动AI技术发展中的关键作用。
#
# 5. **AI工具竞争加剧**：AWS推出Strands Agents的同时，OpenAI也发布了Codex，显示主要AI公司正在智能体市场展开直接竞争，这可能会加速技术创新并使开发者受益。
# ```
#
# The entire workflow was completed successfully. The news article about AWS introducing Strands Agents SDK was translated into Chinese, reviewed for quality, refined based on feedback (such as standardizing terminology like "AI智能体" for "agentic AI"), and finally, five key insights were generated that would be valuable for Chinese-speaking readers.
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '\n\nThe workflow has completed successfully! All four tasks (translate, review, refine, and generate insights) have been processed. I\'ll provide the translated content from each step:\n\n## Translation Results\n\n### Initial Chinese Translation:\n```\n# AWS推出Strands Agents SDK\n\n许多开发者发现代理型人工智能难以使用，因此新的SDK旨在帮助他们部署该技术并连接模型和工具。该工具包还与AWS的SDLC策略保持一致。\n\nEsther Shittu\n作者：Esther Shittu，新闻记者\n发布日期：2025年5月16日\n\nAWS周五推出了Strands Agents，一个开源SDK。\n\n据AWS介绍，Strands Agents是一个模型驱动的工具包，用几行代码构建和运行AI代理。使用Strands，开发者可以定义提示和工具列表来构建代理，测试它并将其部署到云端。\n\nAWS表示，该SDK连接了两个组件：模型和工具。它计划代理的下一步行动并使用先进的推理能力执行工具。\n\n开发者面临的代理挑战\nStrands Agents是AWS帮助开发者将代理型AI整合到工作流程中的尝试。目前，开发者对代理型AI工具持有不同观点。\n\n"有些人欣然接受，有些人则保持怀疑，"RedMonk分析师Rachel Stephens表示。\n\n部分挑战在于，许多开发者发现目前开发和管理代理工作流的方法很困难。\n\n"应用程序开发者在一方面利用LLM（大型语言模型）驱动的任务执行灵活性和另一方面控制这些代理工作流结果的概率特性之间，难以找到正确平衡，"Omdia（Informa TechTarget的一个部门）分析师Torsten Volk说。\n\n他补充说，基于工作流的工具通常需要比企业中典型找到的更多技能和专业知识，这意味着许多AI项目面临被放弃的威胁。通过Strands，AWS承诺开发者不需要"硬编码工作流"，Volk继续说。相反，他们可以使用自己选择的LLM来完成任务。\n\n"如果Strands能够用一种更简单的方法替代复杂工作流，依靠LLM来构建如何使用模型、思考链和调用工具，开发者会被吸引，"Volk说。"大型工具库的可用性将是另一个重要因素，因为工具集成是另一个关键的开发者痛点。"\n\n## AWS策略\nStrands Agents还与AWS更好地集成软件开发生命周期（SDLC）的战略保持一致。\n\n"AWS长期以来一直是生产代码的目的地，但历史上难以在SDLC其他部分获得牵引力，"Stephens说。\n\n该云提供商最近通过包括将代理集成到GitLab和GitHub中的发布来解决这一问题。\n\n"这些集成表明了生态系统焦点和构建贯穿SDLC的集成的意图，"Stephens继续说。她补充说，Strands Agents也是SDLC的一部分。\n\n"它旨在帮助开发者设计和构建代理，在本地测试它们并将它们部署到云端，"她说。\n\n虽然集成角度更为切线，但AWS使用独立生成式AI供应商Anthropic的模型复杂协议（MCP），"这打开了许多生态系统的门，"Stephens说。"MCP是连接代理工具的事实标准。"\n\nStrands Agents可以在任何地方运行，并支持任何具有推理和工具使用能力的模型，包括Amazon Bedrock和Ollama中的模型。作为开源系统，Strands Agents包括来自社区其他成员的贡献，包括埃森哲、Anthropic、Meta和普华永道。开发者现在可以在GitHub上开始使用这些工具。\n\n与此同时，OpenAI周五推出了Codex，一个基于云的软件工程代理，可以并行处理编写功能、回答关于代码库的问题和修复错误等任务。\n\n它由codex-1提供支持，这是OpenAI的o3 LLM的一个版本，针对软件工程进行了优化，并通过强化学习进行了训练，OpenAI表示。\n\n新代理现在将向ChatGPT Pro、Enterprise和Team用户推出。Plus和Edu用户也将很快能够使用它。\n\nEsther Shittu是Informa TechTarget的新闻作家和播客主持人，报道AI软件和系统。\n```\n\n### Review Feedback:\n```\n整体来说，这篇翻译质量较高，大部分内容准确传达了原文的意思。以下是一些具体反馈和建议：\n\n1. 标题和小标题翻译准确\n2. 技术术语如"SDK"、"SDLC"、"LLM"等保留了英文，这是正确的做法\n\n需要改进的地方：\n\n1. "代理型人工智能"可改为更专业的"智能体AI"或"AI智能体"（agentic AI的标准翻译）\n2. "几行代码构建和运行AI代理"中的"代理"应统一为"智能体"\n3. "工具包"和"工具集"的翻译可以更加一致\n4. "部署到云端"可以考虑译为"部署至云环境"，更符合技术文档表述\n5. "概率特性"（probabilistic character）的翻译不够准确，可改为"概率性特征"或"不确定性特征"\n6. "埃森哲"应直接使用英文名称"Accenture"，因为这是公司名称\n7. 部分句子结构可以调整得更符合中文表达习惯，比如"应用程序开发者在...之间，难以找到正确平衡"可改为"应用程序开发者难以在...之间找到正确平衡"\n8. 日期格式"2025年5月16日"符合中文习惯，翻译正确\n\n总体建议：对技术术语的翻译需要更加一致，句式可以更加符合中文的表达习惯，适当增加连接词使文章更流畅。\n```\n\n### Refined Translation:\n```\n# AWS推出Strands Agents SDK\n\n许多开发者发现AI智能体（agentic AI）难以使用，因此新的SDK旨在帮助他们部署该技术并连接模型和工具。该工具包还与AWS的SDLC策略保持一致。\n\nEsther Shittu\n作者：Esther Shittu，新闻记者\n发布日期：2025年5月16日\n\nAWS周五推出了Strands Agents，一个开源SDK。\n\n据AWS介绍，Strands Agents是一个模型驱动的工具包，用几行代码即可构建和运行AI智能体。使用Strands，开发者可以定义提示和工具列表来构建智能体，测试它并将其部署至云环境。\n\nAWS表示，该SDK连接了两个核心组件：模型和工具。它规划智能体的下一步行动并利用先进的推理能力执行工具。\n\n开发者面临的智能体挑战\nStrands Agents是AWS帮助开发者将AI智能体整合到工作流程中的尝试。目前，开发者对AI智能体工具持有不同观点。\n\n"有些人欣然接受，有些人则保持怀疑，"RedMonk分析师Rachel Stephens表示。\n\n部分挑战在于，许多开发者发现目前开发和管理智能体工作流的方法很困难。\n\n"应用程序开发者难以在利用LLM（大型语言模型）驱动的任务执行灵活性和控制这些智能体工作流结果的不确定性特征之间找到正确平衡，"Omdia（Informa TechTarget的一个部门）分析师Torsten Volk说。\n\n他补充说，基于工作流的工具通常需要比企业中通常具备的更多技能和专业知识，这意味着许多AI项目面临被放弃的风险。通过Strands，AWS承诺开发者不需要"硬编码工作流"。相反，他们可以使用自己选择的LLM来完成任务。\n\n"如果Strands能够用一种更简单的方法替代复杂工作流，依靠LLM来构建如何使用模型、思考链和调用工具，开发者会被吸引，"Volk说。"大型工具库的可用性将是另一个重要因素，因为工具集成是另一个关键的开发者痛点。"\n\n## AWS策略\nStrands Agents还与AWS更好地集成软件开发生命周期（SDLC）的战略保持一致。\n\n"AWS长期以来一直是生产代码的目的地，但历史上难以在SDLC其他部分获得牵引力，"Stephens说。\n\n该云提供商最近通过包括将智能体集成到GitLab和GitHub中的发布来解决这一问题。\n\n"这些集成表明了生态系统焦点和构建贯穿SDLC的集成的意图，"Stephens继续说道。她补充说，Strands Agents也是SDLC战略的一部分。\n\n"它旨在帮助开发者设计和构建智能体，在本地测试它们并将它们部署至云环境，"她说。\n\n虽然集成角度相对间接，但AWS使用独立生成式AI供应商Anthropic的模型复杂协议（MCP），"这打开了许多生态系统的大门，"Stephens说。"MCP是连接智能体工具的事实标准。"\n\nStrands Agents可以在任何地方运行，并支持任何具有推理和工具使用能力的模型，包括Amazon Bedrock和Ollama中的模型。作为开源系统，Strands Agents包括来自社区其他成员的贡献，包括Accenture、Anthropic、Meta和PwC。开发者现在可以在G ...

# %%
import os
import base64
##https://github.com/awslabs/amazon-bedrock-agent-samples/tree/main/examples/agent_observability/deploy-langfuse-on-ecs-fargate-with-typescript-cdk

secret_key="sk-lf-46839148-58c4-4cef-9115-75623c78553a"
public_key="pk-lf-0a30d748-a9b9-4325-9fd6-fa09a44ff3b5"
os.environ["LANGFUSE_HOST"] = "https://d3og9zzfs5n481.cloudfront.net" 

# Set up endpoint
otel_endpoint = str(os.environ.get("LANGFUSE_HOST")) + "/api/public/otel/v1/traces"

# Create authentication token:

auth_token = base64.b64encode(f"{public_key}:{secret_key}".encode()).decode()
os.environ["OTEL_EXPORTER_OTLP_ENDPOINT"] = otel_endpoint
os.environ["OTEL_EXPORTER_OTLP_HEADERS"] = f"Authorization=Basic {auth_token}"

# %%
from mcp import stdio_client, StdioServerParameters
from strands import Agent
from strands.tools.mcp import MCPClient
from strands_tools import workflow
from mcp.client.streamable_http import streamablehttp_client
import uuid
from strands.models import BedrockModel

bedrock_model = BedrockModel(
    model_id="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    cache_tools="default"
)
session_id = str(uuid.uuid4())
# Connect to an MCP server using stdio transport
stdio_mcp_client = MCPClient(lambda: stdio_client(
    StdioServerParameters(command="npx", args=["-y", "tavily-mcp@0.1.3"],env={"TAVILY_API_KEY": "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"})
))

streamable_http_mcp_client = MCPClient(lambda: streamablehttp_client(
    url="https://har89we10a.execute-api.us-east-1.amazonaws.com/Prod/mcp",
    headers={"Authorization":"Bearer 123456"}))

# Create an agent with MCP tools
with streamable_http_mcp_client:
    with stdio_mcp_client:
        # Get the tools from the MCP server
        tools = stdio_mcp_client.list_tools_sync()+streamable_http_mcp_client.list_tools_sync()
        for tool in tools:
            print(tool.tool_name, tool.tool_spec)

        # Sequential workflow processing
        def process_workflow(topic):
            # Create specialized agents
            researcher = Agent(
                model = bedrock_model,
                system_prompt="You are a research specialist. Find key information. you can use tool to get current time at first",
                               tools=tools, callback_handler=custom_callback_handler,
                               trace_attributes={
                        "session.id": session_id,
                        "user.id": "river@domain.com",
                        "tags": [
                            "Agent-SDK",
                            "Okatank-Project",
                            "Observability-Tags",
                        ]
                    })
            analyst = Agent(
                    model = bedrock_model,
                    system_prompt="You analyze research data and extract insights." ,
                                trace_attributes={
                        "session.id": session_id,
                        "user.id": "river@domain.com",
                        "tags": [
                            "Agent-SDK",
                            "Okatank-Project",
                            "Observability-Tags",
                        ]
                    })
            writer = Agent(
                model = bedrock_model,
                system_prompt="You create polished reports based on analysis.",
                           trace_attributes={
                        "session.id": session_id,
                        "user.id": "river@domain.com",
                        "tags": [
                            "Agent-SDK",
                            "Okatank-Project",
                            "Observability-Tags",
                        ]
                    })
            # # Step 1: Research
            research_results = researcher(f"Research the latest developments in {topic}")

            # # Step 2: Analysis
            analysis = analyst(f"Analyze these research findings: {research_results}")
            # print("\n----------summary---------\n\n")
            # print(analysis.metrics.get_summary())

            # print(f"Total tokens: {analysis.metrics.accumulated_usage}")
            # print(f"Execution time: {sum(analysis.metrics.cycle_durations):.2f} seconds")
            # print(f"Tools used: {list(analysis.metrics.tool_metrics.keys())}")
            # # Step 3: Report writing
            final_report = writer(f"Create a report based on this analysis: {analysis}")
            
            # print(f"\n----final------:\n{final_report}")

        process_workflow("AI Agent technology trends")
# Out:
# Error parsing JSON response: 1 validation error for JSONRPCMessage
#   Invalid JSON: EOF while parsing a value at line 1 column 0 [type=json_invalid, input_value=b'', input_type=bytes]
#     For further information visit https://errors.pydantic.dev/2.11/v/json_invalid
# tavily-search {'inputSchema': {'json': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'Search query'}, 'search_depth': {'type': 'string', 'enum': ['basic', 'advanced'], 'description': "The depth of the search. It can be 'basic' or 'advanced'", 'default': 'basic'}, 'topic': {'type': 'string', 'enum': ['general', 'news'], 'description': 'The category of the search. This will determine which of our agents will be used for the search', 'default': 'general'}, 'days': {'type': 'number', 'description': "The number of days back from the current date to include in the search results. This specifies the time frame of data to be retrieved. Please note that this feature is only available when using the 'news' search topic", 'default': 3}, 'time_range': {'type': 'string', 'description': "The time range back from the current date to include in the search results. This feature is available for both 'general' and 'news' search topics", 'enum': ['day', 'week', 'month', 'year', 'd', 'w', 'm', 'y']}, 'max_results': {'type': 'number', 'description': 'The maximum number of search results to return', 'default': 10, 'minimum': 5, 'maximum': 20}, 'include_images': {'type': 'boolean', 'description': 'Include a list of query-related images in the response', 'default': False}, 'include_image_descriptions': {'type': 'boolean', 'description': 'Include a list of query-related images and their descriptions in the response', 'default': False}, 'include_raw_content': {'type': 'boolean', 'description': 'Include the cleaned and parsed HTML content of each search result', 'default': False}, 'include_domains': {'type': 'array', 'items': {'type': 'string'}, 'description': 'A list of domains to specifically include in the search results, if the user asks to search on specific sites set this to the domain of the site', 'default': []}, 'exclude_domains': {'type': 'array', 'items': {'type': 'string'}, 'description': 'List of domains to specifically exclude, if the user asks to exclude a domain set this to the domain of the site', 'default': []}}, 'required': ['query']}}, 'name': 'tavily-search', 'description': "A powerful web search tool that provides comprehensive, real-time results using Tavily's AI search engine. Returns relevant web content with customizable parameters for result count, content type, and domain filtering. Ideal for gathering current information, news, and detailed web content analysis."}
# tavily-extract {'inputSchema': {'json': {'type': 'object', 'properties': {'urls': {'type': 'array', 'items': {'type': 'string'}, 'description': 'List of URLs to extract content from'}, 'extract_depth': {'type': 'string', 'enum': ['basic', 'advanced'], 'description': "Depth of extraction - 'basic' or 'advanced', if usrls are linkedin use 'advanced' or if explicitly told to use advanced", 'default': 'basic'}, 'include_images': {'type': 'boolean', 'description': 'Include a list of images extracted from the urls in the response', 'default': False}}, 'required': ['urls']}}, 'name': 'tavily-extract', 'description': 'A powerful web content extraction tool that retrieves and processes raw content from specified URLs, ideal for data collection, content analysis, and research tasks.'}
# getTime {'inputSchema': {'json': {'type': 'object', 'properties': {}, 'required': []}}, 'name': 'getTime', 'description': 'Get the current UTC date and time.'}
# getWeather {'inputSchema': {'json': {'type': 'object', 'properties': {'city': {'type': 'string', 'description': 'Name of the city to get weather for'}}, 'required': ['city']}}, 'name': 'getWeather', 'description': 'Get the current weather for a city.'}
# countS3Buckets {'inputSchema': {'json': {'type': 'object', 'properties': {}, 'required': []}}, 'name': 'countS3Buckets', 'description': 'Count the number of S3 buckets.'}
# I'll research the latest developments in AI Agent technology trends for you. First, let's check the current time to ensure we get the most up-to-date information.
# USING TOOL: getTime /
#
#
# Now I'll search for the latest information on AI Agent technology trends:
# USING TOOL: tavily-search /
#
# USING TOOL: tavily-search / {"query": "l
#
# USING TOOL: tavily-search / {"query": "latest dev
#
# USING TOOL: tavily-search / {"query": "latest developm
#
# USING TOOL: tavily-search / {"query": "latest developments A
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agen
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technolog
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology tren
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 202
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 2025"
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 2025", "
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 2025", "search_depth
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 2025", "search_depth": "advanc
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 2025", "search_depth": "advanced"
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 2025", "search_depth": "advanced",
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 2025", "search_depth": "advanced", "max_re
#
# USING TOOL: tavily-search / {"query": "latest developments AI Agent technology trends 2025", "search_depth": "advanced", "max_results": 10}
#
#
# I'll gather more specific information about AI agent technologies:
# USING TOOL: tavily-search /
#
# USING TOOL: tavily-search / {"max
#
# USING TOOL: tavily-search / {"max_res
#
# USING TOOL: tavily-search / {"max_results"
#
# USING TOOL: tavily-search / {"max_results": 10
#
# USING TOOL: tavily-search / {"max_results": 10, "sear
#
# USING TOOL: tavily-search / {"max_results": 10, "search
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth"
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth":
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advan
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced"
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "qu
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI ag
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technolo
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology m
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multi
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimoda
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimodal auton
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimodal autonomous c
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimodal autonomous cap
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimodal autonomous capab
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimodal autonomous capabili
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimodal autonomous capabilities m
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimodal autonomous capabilities market g
#
# USING TOOL: tavily-search / {"max_results": 10, "search_depth": "advanced", "query": "AI agent technology multimodal autonomous capabilities market growth 2025"}
#
#
# Let me get more information about recent innovations and practical applications:
# USING TOOL: tavily-search /
#
# USING TOOL: tavily-search / {"max
#
# USING TOOL: tavily-search / {"max_results"
#
# USING TOOL: tavily-search / {"max_results": 5
#
# USING TOOL: tavily-search / {"max_results": 5, "searc
#
# USING TOOL: tavily-search / {"max_results": 5, "search_
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advance
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced"
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "qu
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query":
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent techn
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology pr
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology practi
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology practical ap
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology practical applicat
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology practical application
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology practical applications
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology practical applications recent in
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology practical applications recent innovations
#
# USING TOOL: tavily-search / {"max_results": 5, "search_depth": "advanced", "query": "AI agent technology practical applications recent innovations 2025"}
#
#
#
#
# Based on the research I've conducted, here's a comprehensive overview of the latest developments in AI Agent technology trends:
#
# # Latest Developments in AI Agent Technology Trends (2025)
#
# ## Market Growth and Projections
#
# The AI agent technology market is experiencing explosive growth:
# - The global AI agents market is valued at $7.92 billion in 2025 and projected to reach $236.03 billion by 2034, with a CAGR of 45.82% (Precedence Research)
# - The multimodal AI market was valued at $1.6 billion in 2024 and is growing at a CAGR of 32.7% through 2034 (GM Insights)
# - DeepBrain AI reports the total AI agent market is expected to reach $216.8 billion by 2035
#
# ## Key Technology Advancements
#
# ### 1. Agentic AI Development
#
# Agentic AI has emerged as the dominant innovation narrative in 2025, characterized by:
# - Advanced reasoning and memory capabilities
# - Autonomous systems that can plan, reason, use tools, and perform complex tasks
# - Ability to make independent decisions with minimal human intervention
#
# Major developments:
# - OpenAI has released a new suite of tools including the Responses API and an open-source Agents SDK, designed to simplify the creation of AI agents
# - Microsoft announced at their Build 2025 conference that "We've entered the era of AI agents" and is focused on making AI agents more capable and secure
#
# ### 2. Multimodal AI Integration
#
# Multimodal AI is becoming standard rather than optional:
# - By 2026, Gartner predicts 60% of enterprise applications will be built using AI models that combine two or more modalities
# - Interactive multimodal AI is growing at a CAGR of 34.4% (2025-2034)
# - Audio data in multimodal AI applications is expanding at a 33.1% CAGR (2025-2034)
# - Companies like Sarvam AI are demonstrating audio capabilities in multimodal AI by developing enterprise voice agents with enhanced reasoning
#
# ### 3. AI Agent Specialization and Market Segments
#
# The AI agent market is diversifying into specialized categories:
# - Autonomous Agents: $22.5 billion projected for 2025 (+50% growth)
# - AI Humans: $12.8 billion projected for 2025 (+60% growth)
# - Industry-Specific Agents: $28 billion projected for 2025 (+40% growth)
# - Personal AI Assistants: $13 billion projected for 2025 (+45% growth)
#
# ## Practical Applications and Use Cases
#
# ### 1. Business and Enterprise Applications
#
# - **Software Development**: 15 million developers are using GitHub Copilot, with features like agent mode and code review streamlining coding, checking, deployment and troubleshooting
# - **Marketing**: 46% of companies are working with or planning to use AI for autonomous decisioning capabilities (State of Martech 2025)
# - **Manufacturing**: AI agents are predicting and scheduling maintenance, improving quality control, and enhancing production processes
# - **Supply Chain Optimization**: Enhanced AI reasoning capabilities are transforming inventory management and logistics
#
# ### 2. Cross-Industry Innovations
#
# - **"Service-as-a-Software" Models**: Emerging business models where AI agents form ecosystems rather than traditional software stacks
# - **Integrated RAG Services**: Cloud providers are focusing on Retrieval-Augmented Generation to optimize existing services
# - **Edge AI**: Moving AI capabilities to edge computing for tasks requiring quick action (self-driving cars, smart homes)
#
# ## Future Outlook and Challenges
#
# - Experts warn against an "agentic AI hype cycle," noting that investors shouldn't expect profitability in the next 3-5 years
# - Industry leaders like IBM acknowledge that while the groundwork has been laid for autonomous agents, the technology is "not fully there yet"
# - Key challenges include improving contextual reasoning and testing for edge cases
# - Open standards will play a crucial role in enabling seamless integration across different systems and machines
#
# As we move further into 2025, AI agent technology continues to advance rapidly, with practical applications emerging across industries and significant investments driving innovation in autonomous capabilities, multimodal processing, and specialized agent deployment.# Analysis of AI Agent Technology Trends Research Findings (2025)
#
# ## Key Insights from Market Projections
#
# The research reveals extraordinary growth expectations for the AI agent market:
# - The projected CAGR of 45.82% (reaching $236.03B by 2034) indicates AI agents represent one of the fastest-growing technology sectors
# - The nearly 30x growth projection (from $7.92B to $236.03B) suggests market expectations of transformational, not incremental, adoption
# - The multimodal AI growth rate (32.7% CAGR) is lower than the overall agent market, indicating specialized agents may be driving greater value
#
# ## Critical Technological Developments
#
# The findings highlight three interconnected technological shifts:
#
# 1. **Agentic AI as the Central Narrative**: Major platforms (OpenAI, Microsoft) are pivoting their development strategies toward agentic approaches. This represents a fundamental shift from passive AI models that respond to prompts toward autonomous systems that can initiate actions and complete complex workflows.
#
# 2. **Multimodal Integration as Core Infrastructure**: Gartner's prediction that 60% of enterprise applications will use multiple modalities by 2026 suggests multimodal AI is rapidly becoming fundamental infrastructure rather than a specialized capability.
#
# 3. **Market Segmentation Indicates Maturation**: The emergence of four distinct market segments (Autonomous Agents, AI Humans, Industry-Specific Agents, Personal AI Assistants) with different growth trajectories indicates the market is moving beyond early-stage innovation toward specialized applications with clearer value propositions.
#
# ## Implications for Business Implementation
#
# The research suggests different adoption patterns across sectors:
#
# - **Developer Tools Lead Adoption**: With 15 million GitHub Copilot users, developer tools appear to be the most mature application area, likely because developers can directly implement and customize agent technology
# - **Marketing Shows Strong Early Interest**: The 46% of companies planning to use AI for autonomous decisions in marketing indicates this vertical may be the next major adoption area
# - **Manufacturing and Supply Chain**: These appear to be high-potential but less immediately adopted applications, focused on optimization rather than replacement
#
# ## Critical Gaps and Limitations
#
# Several important limitations are evident in the research:
#
# 1. **Hype vs. Reality Gap**: The warning about an "agentic AI hype cycle" and IBM's acknowledgment that autonomous agents are "not fully there yet" suggests a significant disconnect between market projections and current technical capabilities
#
# 2. **Limited ROI Evidence**: The research lacks concrete ROI metrics from implemented solutions, noting investors shouldn't expect profitability for 3-5 years
#
# 3. **Technical Challenges Remain**: Contextual reasoning and edge case testing are identified as ongoing challenges, suggesting current agent reliability may be lower than projected adoption rates would require
#
# ## Research Implications
#
# This analysis suggests several strategic considerations:
#
# 1. The market is shifting from exploratory AI to implementation-focused agent technology, with major platforms building infrastructure to support this transition
#
# 2. Early adoption appears concentrated in knowledge work and digital domains, with physical-world applications developing more gradually
#
# 3. The rapid segmentation of the market suggests organizations should develop targeted, domain-specific agent strategies rather than general AI approaches
#
# 4. The significant gap between projected growth and acknowledged technical limitations suggests careful evaluation of vendor claims is essential# AI Agent Technology Trends: Market Analysis and Strategic Implications
# **2025 Research Report**
#
# ## Executive Summary
#
# This report analyzes emerging trends in AI agent technology based on comprehensive market research conducted in 2025. Our findings reveal extraordinary growth projections in the AI agent market, with a projected compound annual growth rate (CAGR) of 45.82%, potentially reaching $236.03 billion by 2034. This represents a nearly 30-fold increase from the current $7.92 billion valuation, signaling transformational rather than incremental adoption across industries. The research identifies significant technological developments, varying implementation patterns across sectors, and critical gaps between market expectations and current capabilities.
#
# ## Market Growth Projections
#
# The AI agent market demonstrates exceptional growth metrics that position it among the fastest-growing technology sectors:
#
# - **Overall Market Trajectory**: 45.82% CAGR through 2034, reaching $236.03B
# - **Multimodal AI Growth**: 32.7% CAGR, notably lower than the overall agent market
# - **Market Expansion Scale**: Projected 30x growth from current $7.92B valuation
#
# These figures suggest investors and enterprises anticipate AI agents will fundamentally transform business operations across multiple sectors, not simply provide incremental improvements to existing processes.
#
# ## Key Technological Developments
#
# Three interconnected technological shifts are reshaping the AI landscape:
#
# ### 1. Agentic AI as the Dominant Paradigm
#
# Major platforms including OpenAI and Microsoft have strategically pivoted toward agentic approaches, representing a fundamental shift from reactive AI systems to proactive, autonomous agents. This transition moves AI from:
# - Passive models responding to human prompts
# - To autonomous systems initiating actions and managing complex workflows
#
# ### 2. Multimodal Integration Becoming Standard Infrastructure
#
# With Gartner predicting 60% of enterprise applications will incorporate multiple modalities by 2026, multimodal AI is rapidly transitioning from specialized capability to fundamental infrastructure. This suggests successful AI implementation will increasingly require:
# - Integration across text, image, audio, and video processing
# - Seamless handling of mixed-input formats
# - Contextual understanding across modality boundaries
#
# ### 3. Market Segmentation Indicating Maturation
#
# The emergence of four distinct market segments signals the AI agent market is evolving beyond early innovation toward specialized applications with clearer value propositions:
#
# | Market Segment | Key Characteristics | Adoption Indicators |
# |----------------|---------------------|---------------------|
# | Autonomous Agents | Task-focused, workflow automation | Highest early enterprise adoption |
# | AI Humans | Human-like interfaces, customer interaction | Strong service sector interest |
# | Industry-Specific Agents | Vertical specialization, domain expertise | Varied by industry maturity |
# | Personal AI Assistants | Consumer-focused, productivity tools | High volume, lower revenue per unit |
#
# ## Business Implementation Patterns
#
# Implementation patterns vary significantly across sectors, with clear leaders emerging:
#
# **Developer Tools**: With 15 million GitHub Copilot users, developer tools represent the most mature application area, likely due to:
# - Direct implementation capability within the developer community
# - Clear productivity benefits with measurable outcomes
# - Lower barriers to adoption for technical teams
#
# **Marketing Applications**: The research indicates 46% of companies plan to use AI for autonomous marketing decisions, suggesting this vertical may be the next major adoption area, driven by:
# - Data-rich environments
# - Clear ROI potential
# - Existing algorithmic decision frameworks
#
# **Manufacturing and Supply Chain**: These sectors show high potential but slower early adoption, focused primarily on optimization rather than replacement of existing systems.
#
# ## Critical Limitations and Gaps
#
# Despite robust growth projections, several significant limitations warrant attention:
#
# 1. **Hype vs. Reality Gap**: Warnings about an "agentic AI hype cycle" and acknowledgments from industry leaders that autonomous agents are "not fully there yet" indicate a disconnect between market expectations and current capabilities.
#
# 2. **Limited ROI Evidence**: The research lacks substantial ROI metrics from implemented solutions, with investors advised not to expect profitability for 3-5 years—suggesting early adopters should plan for extended development timelines.
#
# 3. **Persistent Technical Challenges**: Issues with contextual reasoning and edge case handling remain significant hurdles, indicating that current agent reliability may fall short of the requirements implied by projected adoption rates.
#
# ## Strategic Implications
#
# Organizations evaluating AI agent technology should consider the following strategic implications:
#
# 1. **Targeted Implementation Strategy**: The rapid segmentation of the market suggests organizations should develop domain-specific agent strategies rather than general AI approaches.
#
# 2. **Realistic Timeline Planning**: The gap between projected growth and acknowledged technical limitations necessitates careful evaluation of vendor claims and conservative implementation timelines.
#
# 3. **Infrastructure Readiness**: As multimodal AI becomes standard infrastructure, organizations should assess their readiness to integrate multiple data types and formats.
#
# 4. **Vertical-Specific Approach**: Different industries show varying adoption patterns and use cases, indicating the need for sector-specific strategies rather than universal approaches.
#
# ## Conclusion
#
# The AI agent market demonstrates exceptional growth potential alongside clear signs of market maturation. The transition from exploratory AI to implementation-focused agent technology represents a fundamental shift in how organizations will leverage artificial intelligence. However, the significant gap between projected growth and current technical capabilities suggests organizations should proceed with strategic caution, developing targeted implementation plans that account for both the transformative potential and practical limitations of current AI agent technology.
# Session termination failed: 403

# %%
import re
tool_name = "tavily-search"
tool_name_pattern = r"^[a-zA-Z][a-zA-Z0-9_\-]*$"
valid_name_pattern = bool(re.match(tool_name_pattern, tool_name))
valid_name_pattern
# Out:
# True

# %%
# Check workflow status
# agent("Show me the status of the translation workflow")
# Out:
# I'll show you the current status of the translation workflow again.
# Tool #6: workflow
#
#
#
#
# Here is the current status of your translation workflow:
#
# **Workflow ID:** tech_news_translation_workflow
# **Overall Status:** Completed
# **Progress:** 100.0% (4/4 tasks completed)
#
# **Task Details:**
#
# 1. **English to Chinese Translation**
#    - Description: Translate the English AWS Strands Agents SDK news article to Chinese
#    - Status: Completed
#    - Duration: 10.84 seconds
#
# 2. **Translation Review**
#    - Description: Review the Chinese translation draft and provide feedback
#    - Status: Completed
#    - Duration: 7.86 seconds
#
# 3. **Refine Translation**
#    - Description: Refine the Chinese translation based on reviewer feedback
#    - Status: Completed
#    - Duration: 7.61 seconds
#
# 4. **Generate Insights**
#    - Description: Generate 3-5 key insights from the news article in both English and Chinese
#    - Status: Completed
#    - Duration: 11.26 seconds
#
# All tasks in the workflow have been completed successfully. As mentioned previously, the workflow system manages task orchestration but does not appear to provide access to the content outputs of the tasks directly. If you need to access the content (translations, reviews, or insights), we would need to design a workflow that includes steps to save outputs to an accessible location.
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '\n\n\n\nHere is the current status of your translation workflow:\n\n**Workflow ID:** tech_news_translation_workflow\n**Overall Status:** Completed\n**Progress:** 100.0% (4/4 tasks completed)\n\n**Task Details:**\n\n1. **English to Chinese Translation**\n   - Description: Translate the English AWS Strands Agents SDK news article to Chinese\n   - Status: Completed\n   - Duration: 10.84 seconds\n\n2. **Translation Review**\n   - Description: Review the Chinese translation draft and provide feedback\n   - Status: Completed\n   - Duration: 7.86 seconds\n\n3. **Refine Translation**\n   - Description: Refine the Chinese translation based on reviewer feedback\n   - Status: Completed\n   - Duration: 7.61 seconds\n\n4. **Generate Insights**\n   - Description: Generate 3-5 key insights from the news article in both English and Chinese\n   - Status: Completed\n   - Duration: 11.26 seconds\n\nAll tasks in the workflow have been completed successfully. As mentioned previously, the workflow system manages task orchestration but does not appear to provide access to the content outputs of the tasks directly. If you need to access the content (translations, reviews, or insights), we would need to design a workflow that includes steps to save outputs to an accessible location.'}]}, metrics=EventLoopMetrics(cycle_count=12, tool_metrics={'workflow': ToolMetrics(tool={'toolUseId': 'tooluse_EfuiM_MlRs2wf4Eg6WyIfg', 'name': 'workflow', 'input': {'action': 'status', 'workflow_id': 'tech_news_translation_workflow'}}, call_count=6, success_count=6, error_count=0, total_time=41.0684449672699)}, cycle_durations=[4.625037670135498, 5.783435344696045, 7.125268459320068, 4.041921138763428, 6.284534931182861, 7.380441427230835], traces=[<strands.telemetry.metrics.Trace object at 0x7ff9c82f4d70>, <strands.telemetry.metrics.Trace object at 0x7ff9c82e3230>, <strands.telemetry.metrics.Trace object at 0x7ff9ca632f10>, <strands.telemetry.metrics.Trace object at 0x7ff9b47fc260>, <strands.telemetry.metrics.Trace object at 0x7ff9c814ff70>, <strands.telemetry.metrics.Trace object at 0x7ff9c814e350>, <strands.telemetry.metrics.Trace object at 0x7ff9c895f570>, <strands.telemetry.metrics.Trace object at 0x7ff9b69e4550>, <strands.telemetry.metrics.Trace object at 0x7ff9b69e44b0>, <strands.telemetry.metrics.Trace object at 0x7ff9b69e4af0>, <strands.telemetry.metrics.Trace object at 0x7ff9b69e4370>, <strands.telemetry.metrics.Trace object at 0x7ff9c814e2b0>], accumulated_usage={'inputTokens': 40857, 'outputTokens': 1774, 'totalTokens': 42631}, accumulated_metrics={'latencyMs': 65849}), state={})

# %%
agent.tool.workflow(action="status", workflow_id="news_translation_workflow")
# Out:
# {'toolUseId': 'tooluse_workflow_954432813',
#  'status': 'success',
#  'content': [{'text': 'Workflow ID: news_translation_workflow\nOverall Status: running\nProgress: 100.0% (4/4)\nActive Tasks: 3\nCompleted Tasks: 4\nPending Tasks: 0\nFailed Tasks: 0\nActive Workers: 0/8\n\nTask Details:\n\nTask: english_to_chinese_translation\nDescription: Translate the English news to Chinese version\nStatus: completed\nPriority: 3\nDuration: -788.31s\n\nTask: translation_review\nDescription: Review the draft translation and provide feedback\nStatus: completed\nPriority: 3\nDuration: -795.19s\n\nTask: translation_refinement\nDescription: Refine the translation based on the feedback to English version\nStatus: completed\nPriority: 3\nDuration: N/A\n\nTask: generate_insights\nDescription: Generate 3-5 insights from the news in both English and Chinese\nStatus: completed\nPriority: 3\nDuration: -803.63s'}]}

# %%
agent("close workflow")
# Out:
# I'll close the translation workflow for you.
# Tool #7: workflow
#
#
#
#
# The workflow with ID "tech_news_translation_workflow" has been successfully deleted. All task resources associated with this workflow have been released and the workflow is no longer active in the system.
#
# Is there anything else you would like help with regarding workflow orchestration or perhaps setting up a new workflow with better output storage capabilities?
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '\n\n\n\nThe workflow with ID "tech_news_translation_workflow" has been successfully deleted. All task resources associated with this workflow have been released and the workflow is no longer active in the system.\n\nIs there anything else you would like help with regarding workflow orchestration or perhaps setting up a new workflow with better output storage capabilities?'}]}, metrics=EventLoopMetrics(cycle_count=14, tool_metrics={'workflow': ToolMetrics(tool={'toolUseId': 'tooluse_PjH-9PyWTGyt4Kbui0sf4A', 'name': 'workflow', 'input': {'action': 'delete', 'workflow_id': 'tech_news_translation_workflow'}}, call_count=7, success_count=7, error_count=0, total_time=41.076600313186646)}, cycle_durations=[4.625037670135498, 5.783435344696045, 7.125268459320068, 4.041921138763428, 6.284534931182861, 7.380441427230835, 7.104897499084473], traces=[<strands.telemetry.metrics.Trace object at 0x7ff9c82f4d70>, <strands.telemetry.metrics.Trace object at 0x7ff9c82e3230>, <strands.telemetry.metrics.Trace object at 0x7ff9ca632f10>, <strands.telemetry.metrics.Trace object at 0x7ff9b47fc260>, <strands.telemetry.metrics.Trace object at 0x7ff9c814ff70>, <strands.telemetry.metrics.Trace object at 0x7ff9c814e350>, <strands.telemetry.metrics.Trace object at 0x7ff9c895f570>, <strands.telemetry.metrics.Trace object at 0x7ff9b69e4550>, <strands.telemetry.metrics.Trace object at 0x7ff9b69e44b0>, <strands.telemetry.metrics.Trace object at 0x7ff9b69e4af0>, <strands.telemetry.metrics.Trace object at 0x7ff9b69e4370>, <strands.telemetry.metrics.Trace object at 0x7ff9c814e2b0>, <strands.telemetry.metrics.Trace object at 0x7ff9c814f750>, <strands.telemetry.metrics.Trace object at 0x7ff9dcfcf110>], accumulated_usage={'inputTokens': 51383, 'outputTokens': 1906, 'totalTokens': 53289}, accumulated_metrics={'latencyMs': 101774}), state={})

# %%
def custom_callback_handler(**kwargs):
    # Process stream data
    if "data" in kwargs:
        print(f"MODEL OUTPUT: {kwargs['data']}")
    elif "current_tool_use" in kwargs and kwargs["current_tool_use"].get("name"):
        print(f"\nUSING TOOL: {kwargs['current_tool_use']['name']}")

# %%
# Initialize Strand agent
agent = Agent(tools=[workflow],callback_handler=custom_callback_handler)
# Create a multi-agent workflow
agent.tool.workflow(
    action="create",
    workflow_id="manual_translation",
    tasks=
        [{'task_id': 'english_to_chinese_translation',
        'description': f'Translate the English AWS Strands Agents SDK news article to Chinese: \n{text}',
        'system_prompt': 'You are an AI tech domain translator specializing in translating technology news from English to Chinese. Translate the provided AWS news article about Strands Agents SDK accurately, maintaining technical terminology and professional tone. Ensure all technical concepts are correctly conveyed in Chinese.',
        'priority': 5},
       {'task_id': 'translation_review',
        'description': 'Review the Chinese translation draft and provide feedback',
        'system_prompt': 'You are a bilingual (English-Chinese) editor specializing in technology content. Review the Chinese translation of the AWS Strands Agents SDK news article. Provide specific feedback on accuracy of technical terms, natural flow in Chinese, any mistranslations, and suggestions for improvement.',
        'dependencies': ['english_to_chinese_translation'],
        'priority': 3},
       {'task_id': 'refine_translation',
        'description': 'Refine the Chinese translation based on reviewer feedback',
        'system_prompt': 'You are an AI tech translator refining a Chinese translation based on reviewer feedback. Incorporate the feedback to improve the translation while maintaining technical accuracy. Provide the final refined version in English.',
        'dependencies': ['translation_review'],
        'priority': 3},
       {'task_id': 'generate_insights',
        'description': 'Generate 3-5 key insights from the news article in both English and Chinese',
        'system_prompt': 'Based on the AWS Strands Agents SDK news article, generate 3-5 key insights about the technology, its implications for developers, AWS strategy, or competitive landscape. Present each insight in both English and Chinese formats.',
        'dependencies': ['refine_translation'],
        'priority': 3}]
)
# Out:
# {'toolUseId': 'tooluse_workflow_829502843',
#  'status': 'success',
#  'content': [{'text': 'Created workflow manual_translation with 4 tasks'}]}

# %%
# Execute workflow (parallel processing where possible)
agent.tool.workflow(action="start", workflow_id="manual_translation")
# Out:
# # AWS推出Strands Agents SDK
#
# 许多开发者发现代理人工智能很困难，因此这个新SDK旨在帮助他们部署该技术并连接模型和工具。该工具包还与AWS的SDLC战略保持一致。
# Esther Shittu
# 作者：
# Esther Shittu，新闻作者
# 发布时间：2025年5月16日
# AWS于周五推出了Strands Agents，一个开源SDK。
#
# 据AWS介绍，Strands Agents是一个模型驱动的工具包，用于通过几行代码构建和运行AI代理。使用Strands，开发者可以定义提示和工具列表来构建代理，测试它并将其部署到云端。
#
# AWS表示，该SDK连接了两个组件：模型和工具。它规划代理的下一步行动并以先进的推理能力执行工具。
#
# 开发者面临的代理挑战
# Strands Agents是AWS帮助开发者将代理AI整合到其工作流程中的尝试。目前，开发者对代理AI工具有不同的观点。
#
# "有些人接受它，有些人则持怀疑态度，"RedMonk分析师Rachel Stephens说。
#
# 部分挑战在于许多开发者发现目前开发和管理代理工作流程的方法很困难。
#
# "应用程序开发者一方面努力在利用LLM（大型语言模型）驱动的任务执行的灵活性，另一方面控制这些代理工作流程结果的概率特性之间找到正确的平衡，"Informa TechTarget旗下Omdia的分析师Torsten Volk说。
#
# 他补充说，基于工作流程的工具通常需要比企业通常拥有的更多技能和专业知识，这意味着许多AI项目面临被放弃的威胁。Volk继续表示，通过Strands，AWS承诺开发者不需要"硬编码工作流程"。相反，他们可以使用自己选择的LLM来完成任务。
#
# "如果Strands能够用更简单的方法替代复杂的工作流程，依靠LLM来构建模型使用方式、思维链接和工具调用，开发者将会被吸引，"Volk说。"大型工具库的可用性也将是另一个重要因素，因为工具集成是另一个关键的开发者痛点。"
#
# ## AWS战略
# Strands Agents也与AWS更好地集成软件开发生命周期(SDLC)的战略相一致。
#
# "AWS长期以来一直是生产代码的目的地，但历史上难以在SDLC的其他部分获得关注，"Stephens说。
#
# 该云提供商最近通过包括将代理集成到GitLab和GitHub的发布来解决这个问题。
#
# "这些集成表明了生态系统重点和构建跨SDLC集成的意图，"Stephens继续说。她补充说，Strands Agents也是SDLC产品。
#
# "它旨在帮助开发者设计和构建代理，在本地测试并部署到云端，"她说。
#
# 集成角度更为间接，尽管AWS使用独立生成式AI供应商Anthropic的模型复杂协议(MCP)，"这打开了许多生态系统的大门，"Stephens说。"MCP是连接代理工具的事实标准。"
#
# Strands Agents可以在任何地方运行，支持任何具有推理和工具使用能力的模型，包括Amazon Bedrock和Ollama中的模型。作为开源系统，Strands Agents包括来自社区其他成员的贡献，包括埃森哲、Anthropic、Meta和普华永道。开发者现在可以在GitHub上开始使用这些工具。
#
# 同时，OpenAI周五推出了Codex，这是一个基于云的软件工程代理，可以同时处理编写功能、回答关于代码库的问题和修复bug等任务。
#
# 它由codex-1驱动，这是OpenAI的o3 LLM的一个版本，为软件工程优化并通过强化学习训练，OpenAI表示。
#
# 这个新代理现在将向ChatGPT Pro、Enterprise和Team用户推出。Plus和Edu用户很快也将能够使用它。
#
# Esther Shittu是Informa TechTarget的新闻作者和播客主持人，专注于AI软件和系统。# Translation Review Feedback
#
# Overall, this is a high-quality translation of the AWS Strands Agents SDK article from English to Chinese. Here are my observations and suggestions for improvement:
#
# ### Strengths:
# 1. The technical terminology is accurately translated (e.g., SDK, SDLC, LLM, etc.)
# 2. The structure of the original article is well preserved
# 3. The translation maintains a professional tone appropriate for a tech news article
# 4. Names and company references are correctly kept in their original form
#
# ### Areas for improvement:
#
# 1. **Term consistency**:
#    - The term "agentic AI" is translated as "代理人工智能" - this is accurate but could be more consistent with how AWS might refer to it in Chinese. Consider using "智能代理AI" if that's the standard term used by AWS in Chinese materials.
#
# 2. **Phrases that could be more idiomatic**:
#    - "面临被放弃的威胁" (face the threat of abandonment) - while accurate, a more natural Chinese expression might be "面临被搁置的风险"
#
# 3. **Date format**:
#    - "2025年5月16日" follows Chinese convention but you might want to check if there's a preferred format for tech publications
#
# 4. **Technical clarifications**:
#    - When translating "model complex protocol (MCP)", you maintained "模型复杂协议(MCP)" which is literal but might not be the standard Chinese term. Consider verifying if there's an official Chinese translation for this protocol term.
#
# 5. **Minor syntax issues**:
#    - In the sentence "Volk继续表示，通过Strands，AWS承诺开发者不需要'硬编码工作流程'", the structure is slightly awkward. A more natural flow might be "通过Strands，AWS承诺开发者不需要'硬编码工作流程'，Volk继续表示"
#
# The translation is accurate and professional, maintaining the technical integrity of the original article while being readable for Chinese audiences. With minor adjustments to some expressions, it would be publication-ready.# AWS推出Strands Agents SDK
#
# 许多开发者发现智能代理AI很困难，因此这个新SDK旨在帮助他们部署该技术并连接模型和工具。该工具包还与AWS的SDLC战略保持一致。
# Esther Shittu
# 作者：
# Esther Shittu，新闻作者
# 发布时间：2025年5月16日
# AWS于周五推出了Strands Agents，一个开源SDK。
#
# 据AWS介绍，Strands Agents是一个模型驱动的工具包，用于通过几行代码构建和运行AI代理。使用Strands，开发者可以定义提示和工具列表来构建代理，测试它并将其部署到云端。
#
# AWS表示，该SDK连接了两个组件：模型和工具。它规划代理的下一步行动并以先进的推理能力执行工具。
#
# 开发者面临的代理挑战
# Strands Agents是AWS帮助开发者将智能代理AI整合到其工作流程中的尝试。目前，开发者对智能代理AI工具有不同的观点。
#
# "有些人接受它，有些人则持怀疑态度，"RedMonk分析师Rachel Stephens说。
#
# 部分挑战在于许多开发者发现目前开发和管理代理工作流程的方法很困难。
#
# "应用程序开发者一方面努力在利用LLM（大型语言模型）驱动的任务执行的灵活性，另一方面控制这些代理工作流程结果的概率特性之间找到正确的平衡，"Informa TechTarget旗下Omdia的分析师Torsten Volk说。
#
# 他补充说，基于工作流程的工具通常需要比企业通常拥有的更多技能和专业知识，这意味着许多AI项目面临被搁置的风险。通过Strands，AWS承诺开发者不需要"硬编码工作流程"，Volk继续表示。相反，他们可以使用自己选择的LLM来完成任务。
#
# "如果Strands能够用更简单的方法替代复杂的工作流程，依靠LLM来构建模型使用方式、思维链接和工具调用，开发者将会被吸引，"Volk说。"大型工具库的可用性也将是另一个重要因素，因为工具集成是另一个关键的开发者痛点。"
#
# ## AWS战略
# Strands Agents也与AWS更好地集成软件开发生命周期(SDLC)的战略相一致。
#
# "AWS长期以来一直是生产代码的目的地，但历史上难以在SDLC的其他部分获得关注，"Stephens说。
#
# 该云提供商最近通过包括将代理集成到GitLab和GitHub的发布来解决这个问题。
#
# "这些集成表明了生态系统重点和构建跨SDLC集成的意图，"Stephens继续说。她补充说，Strands Agents也是SDLC产品。
#
# "它旨在帮助开发者设计和构建代理，在本地测试并部署到云端，"她说。
#
# 集成角度更为间接，尽管AWS使用独立生成式AI供应商Anthropic的模型通信协议(MCP)，"这打开了许多生态系统的大门，"Stephens说。"MCP是连接代理工具的事实标准。"
#
# Strands Agents可以在任何地方运行，支持任何具有推理和工具使用能力的模型，包括Amazon Bedrock和Ollama中的模型。作为开源系统，Strands Agents包括来自社区其他成员的贡献，包括埃森哲、Anthropic、Meta和普华永道。开发者现在可以在GitHub上开始使用这些工具。
#
# 同时，OpenAI周五推出了Codex，这是一个基于云的软件工程代理，可以同时处理编写功能、回答关于代码库的问题和修复bug等任务。
#
# 它由codex-1驱动，这是OpenAI的o3 LLM的一个版本，为软件工程优化并通过强化学习训练，OpenAI表示。
#
# 这个新代理现在将向ChatGPT Pro、Enterprise和Team用户推出。Plus和Edu用户很快也将能够使用它。
#
# Esther Shittu是Informa TechTarget的新闻作者和播客主持人，专注于AI软件和系统。# Key Insights from the AWS Strands Agents SDK News Article
#
# ## English
#
# 1. **Developer Accessibility to Agentic AI**: AWS's new Strands Agents SDK addresses a significant pain point in the AI ecosystem by simplifying how developers can build, test, and deploy AI agents with minimal code, potentially expanding the adoption of agentic AI beyond specialized experts.
#
# 2. **Strategic SDLC Integration**: The release aligns with AWS's broader strategy to integrate more deeply across the software development lifecycle, moving beyond just being a production code destination and extending their influence into development and testing phases.
#
# 3. **Interoperability Through Standards**: By adopting Anthropic's model communication protocol (MCP), AWS is prioritizing ecosystem compatibility and establishing connections between different AI tools and services, reinforcing MCP as the de facto standard for connecting agentic tools.
#
# 4. **Growing Competition in AI Agent Platforms**: The timing of AWS's announcement alongside OpenAI's release of Codex demonstrates the accelerating race to capture the market for AI development platforms, with major players pushing towards more capable and accessible AI agent tools.
#
# 5. **Community-Based Development**: AWS is leveraging open source and community contributions from major players like Accenture, Anthropic, Meta, and PwC, indicating a collaborative approach to advancing AI agent technology rather than a purely proprietary one.
#
# ## Chinese
#
# 1. **智能代理AI的开发者可及性**: AWS的新Strands Agents SDK通过简化开发者如何用最少的代码构建、测试和部署AI代理，解决了AI生态系统中的一个重要痛点，有可能将智能代理AI的应用扩展到专业专家之外。
#
# 2. **战略性SDLC整合**: 此次发布与AWS更广泛的战略相符，旨在更深入地整合整个软件开发生命周期，不仅仅是作为生产代码的目的地，还将其影响力延伸到开发和测试阶段。
#
# 3. **通过标准实现互操作性**: 通过采用Anthropic的模型通信协议(MCP)，AWS优先考虑生态系统兼容性，并建立不同AI工具和服务之间的连接，强化MCP作为连接代理工具的事实标准地位。
#
# 4. **AI代理平台竞争加剧**: AWS公告与OpenAI发布Codex的时机表明，争夺AI开发平台市场的竞赛正在加速，主要玩家正朝着更强大、更易于使用的AI代理工具方向推进。
#
# 5. **基于社区的开发**: AWS正利用来自埃森哲、Anthropic、Meta和普华永道等主要参与者的开源和社区贡献，表明推进AI代理技术采取的是合作方式，而非纯粹的专有方式。
# {'toolUseId': 'tooluse_workflow_133990203',
#  'status': 'success',
#  'content': [{'text': 'Workflow manual_translation completed successfully'}]}
