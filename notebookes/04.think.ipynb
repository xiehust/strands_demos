# %%
from strands import Agent
from strands_tools import think, stop

agent = Agent(tools=[think, stop])

# Basic usage with default system prompt
result = agent.tool.think(
    thought="How might we improve renewable energy storage solutions?",
    cycle_count=3,
    system_prompt="You are an expert energy systems analyst."
)

# Advanced usage with custom system prompt
result = agent.tool.think(
    thought="Analyze the implications of quantum computing on cryptography.",
    cycle_count=2,
    system_prompt="""You are a specialist in quantum computing and cryptography. Analyze this topic deeply,
    considering both technical and practical aspects."""
)

# %%
result
# Out:
# {'toolUseId': 'tooluse_think_691271379',
#  'status': 'error',
#  'content': [{'text': "Error: Validation failed for input parameters: 1 validation error for ThinkTool\nkwargs\n  Field required [type=missing, input_value={'thought': 'Analyze the ...and practical aspects.'}, input_type=dict]\n    For further information visit https://errors.pydantic.dev/2.11/v/missing"}]}

# %%
# !pip install strands-agents-builder
# Out:
# Looking in indexes: https://pypi.org/simple, https://plugin.us-east-1.prod.workshops.aws
# Collecting strands-agents-builder
#   Downloading strands_agents_builder-0.1.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting halo<1.0.0,>=0.0.31 (from strands-agents-builder)
#   Using cached halo-0.0.31.tar.gz (11 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-builder) (3.0.51)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-builder) (14.0.0)
# Requirement already satisfied: strands-agents-tools<1.0.0,>=0.1.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-builder) (0.1.1)
# Requirement already satisfied: strands-agents<1.0.0,>=0.1.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.1.2)
# Collecting log_symbols>=0.0.14 (from halo<1.0.0,>=0.0.31->strands-agents-builder)
#   Downloading log_symbols-0.0.14-py3-none-any.whl.metadata (523 bytes)
# Collecting spinners>=0.0.24 (from halo<1.0.0,>=0.0.31->strands-agents-builder)
#   Downloading spinners-0.0.24-py3-none-any.whl.metadata (576 bytes)
# Requirement already satisfied: termcolor>=1.1.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from halo<1.0.0,>=0.0.31->strands-agents-builder) (2.5.0)
# Requirement already satisfied: colorama>=0.3.9 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from halo<1.0.0,>=0.0.31->strands-agents-builder) (0.4.6)
# Requirement already satisfied: six>=1.12.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from halo<1.0.0,>=0.0.31->strands-agents-builder) (1.17.0)
# Requirement already satisfied: wcwidth in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-builder) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-builder) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-builder) (2.19.1)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.38.18)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.38.18)
# Requirement already satisfied: docstring-parser<0.16.0,>=0.15 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.15)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.9.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.33.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.33.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.33.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (2.11.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (4.13.2)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (2.4.0)
# Requirement already satisfied: anyio>=4.5 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.4.0)
# Requirement already satisfied: httpx>=0.27 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (2.3.5)
# Requirement already satisfied: starlette>=0.27 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.46.2)
# Requirement already satisfied: uvicorn>=0.23.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.34.2)
# Requirement already satisfied: deprecated>=1.2.6 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opentelemetry-api<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opentelemetry-api<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.33.1)
# Requirement already satisfied: requests~=2.7 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (2.32.3)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opentelemetry-proto==1.33.1->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (5.29.4)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opentelemetry-sdk<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.54b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (2025.4.26)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (0.4.0)
# Requirement already satisfied: mem0ai<1.0.0,>=0.1.99 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (0.1.100)
# Requirement already satisfied: opensearch-py<3.0.0,>=2.8.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (2.8.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (11.2.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (2.10.1)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.23.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (9.1.2)
# Requirement already satisfied: openai<2.0.0,>=1.33.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.75.0)
# Requirement already satisfied: posthog<4.0.0,>=3.5.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (3.25.0)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.31 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (2.0.41)
# Requirement already satisfied: distro<2,>=1.7.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.33.0->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.33.0->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (0.10.0)
# Requirement already satisfied: sniffio in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.33.0->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.3.1)
# Requirement already satisfied: tqdm>4 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.33.0->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (4.67.1)
# Requirement already satisfied: httpcore==1.* in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (0.16.0)
# Requirement already satisfied: Events in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from opensearch-py<3.0.0,>=2.8.0->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (0.5)
# Requirement already satisfied: monotonic>=1.5 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from posthog<4.0.0,>=3.5.0->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from posthog<4.0.0,>=3.5.0->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (2.2.1)
# Requirement already satisfied: grpcio>=1.41.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.71.0)
# Requirement already satisfied: numpy>=2.1.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (2.2.6)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (2.10.1)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (3.35.0)
# Requirement already satisfied: greenlet>=1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from sqlalchemy<3.0.0,>=2.0.31->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (3.2.2)
# Collecting ollama<1.0.0,>=0.4.8 (from strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder)
#   Downloading ollama-0.4.8-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (1.3.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.33.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.17.2)
# Requirement already satisfied: h2<5,>=3 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<1.0.0,>=0.1.99->strands-agents-tools<1.0.0,>=0.1.0->strands-agents-builder) (4.1.0)
# Requirement already satisfied: mdurl~=0.1 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-builder) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (1.1.0)
# Requirement already satisfied: click>=7.0 in /fsx/mcp_projects/.venv/lib/python3.13/site-packages (from uvicorn>=0.23.1->mcp<2.0.0,>=1.8.0->strands-agents<1.0.0,>=0.1.0->strands-agents[ollama]<1.0.0,>=0.1.0->strands-agents-builder) (8.2.0)
# Downloading strands_agents_builder-0.1.1-py3-none-any.whl (26 kB)
# Downloading ollama-0.4.8-py3-none-any.whl (13 kB)
# Downloading log_symbols-0.0.14-py3-none-any.whl (3.1 kB)
# Downloading spinners-0.0.24-py3-none-any.whl (5.5 kB)
# Building wheels for collected packages: halo
#   Building wheel for halo (pyproject.toml) ... done
#   Created wheel for halo: filename=halo-0.0.31-py3-none-any.whl size=11335 sha256=b3dd838462bd287a214e345af6fd72daa8af1272ddf72926e4d66ea5aa4b6a0e
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/3b/34/ba/a01884c0ab3ceca7a9c10ba3d3bacd6e77b357bbb3d63ee8e4
# Successfully built halo
# Installing collected packages: spinners, log_symbols, halo, ollama, strands-agents-builder
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [strands-agents-builder]ds-agents-builder]
# Successfully installed halo-0.0.31 log_symbols-0.0.14 ollama-0.4.8 spinners-0.0.24 strands-agents-builder-0.1.1
